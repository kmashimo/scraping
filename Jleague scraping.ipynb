# %% [markdown]
# # Web scraping Jleague profile

# %%
import requests
from bs4 import BeautifulSoup

request = requests.get("https://www.jleague.jp/club/sapporo/day/#profile")
print(request.text)
# Out:
# <!doctype html>
#     <html lang="ja">
#         <head>
# 		<meta charset="utf-8">
# 		<title>北海道コンサドーレ札幌の試合日程・結果：Ｊリーグ.jp</title>
#
# 		<!--meta-->
# 		<meta name="description" content="Ｊ１、Ｊ２、Ｊ３全てのクラブプロフィール、選手名鑑をごちらからご覧いただけます。">
# 		<meta name="keywords" content="Ｊリーグ公式サイト,Ｊ１クラブ,Ｊ２クラブ,Ｊ３クラブ,Ｊ１,Ｊ２,Ｊ３,ヤマザキナビスコカップ,フジゼロックススーパーカップ,Ｊ１昇格プレーオフ,Ｊリーグアウォーズ,J awards,acl,Ｊユースカップ,Ｊリーグ日程,Ｊリーグ結果,Ｊリーグ速報,Ｊリーグ順位">
# 		<meta property="og:title" content="北海道コンサドーレ札幌の試合日程・結果：Ｊリーグ.jp">
# 		<meta property="og:type" content="article">
# 		<meta property="og:description" content="Ｊ１、Ｊ２、Ｊ３全てのクラブプロフィール、選手名鑑をごちらからご覧いただけます。">
# 		<meta property="og:url" content="https://www.jleague.jp/club/sapporo/day/">
# 		<meta property="og:image" content="/ogp/ogimage.png">
# 		<meta property="og:site_name" content="Ｊリーグ.jp（日本プロサッカーリーグ）">
#         <link rel="alternate" media="only screen and (max-width: 640px)" href="https://www.jleague.jp/sp/club/sapporo/day/" />
#             <script>
# (function(){
#   var ua = {
#     iPhone: navigator.userAgent.indexOf('iPhone') != -1,
#     iPad: navigator.userAgent.indexOf('iPad') != -1,
#     iPod: navigator.userAgent.indexOf('iPod') != -1,
#     android: navigator.userAgent.indexOf('Android') != -1,
#     windows: navigator.userAgent.indexOf('Windows Phone') != -1
#   }
#   if(ua.iPhone || ua.iPad || ua.iPod || ua.android || ua.windows){
#
#   	//　通常時
#     // document.write('<meta name="viewport" content="width=1060, user-scalable=1">\n');
#
#     //スカイスクレイパー表示時
#     document.write('<meta name="viewport" content="width=1600, user-scalable=1">\n');
#   }
# }());
# </script>
#
#
#
# 			<meta property="fb:app_id" content="1590035654547971">
# 			<link rel="shortcut icon" href="/favicon.ico">
# 			<link rel="apple-touch-icon" sizes="57x57" href="/favicon/apple-touch-icon-57x57.png">
# 			<link rel="apple-touch-icon" sizes="114x114" href="/favicon/apple-touch-icon-114x114.png">
# 			<link rel="apple-touch-icon" sizes="72x72" href="/favicon/apple-touch-icon-72x72.png">
# 			<link rel="apple-touch-icon" sizes="144x144" href="/favicon/apple-touch-icon-144x144.png">
# 			<link rel="apple-touch-icon" sizes="60x60" href="/favicon/apple-touch-icon-60x60.png">
# 			<link rel="apple-touch-icon" sizes="120x120" href="/favicon/apple-touch-icon-120x120.png">
# 			<link rel="apple-touch-icon" sizes="76x76" href="/favicon/apple-touch-icon-76x76.png">
# 			<link rel="apple-touch-icon" sizes="152x152" href="/favicon/apple-touch-icon-152x152.png">
# 			<link rel="apple-touch-icon" sizes="180x180" href="/favicon/apple-touch-icon-180x180.png">
# 			<!-- <link rel="icon" type="image/png" href="/favicon/favicon-192x192.png" sizes="192x192"> -->
# 			<!-- <link rel="icon" type="image/png" href="/favicon/favicon-160x160.png" sizes="160x160"> -->
# 			<link rel="icon" type="image/png" href="/favicon/favicon-194x194.png" sizes="194x194">
# 			<link rel="icon" type="image/png" href="/favicon/favicon-96x96.png" sizes="96x96">
# 			<link rel="icon" type="image/png" href="/favicon/favicon-16x16.png" sizes="16x16">
# 			<link rel="icon" type="image/png" href="/favicon/favicon-32x32.png" sizes="32x32">
# 			<meta name="msapplication-TileColor" content="#ffffff">
# 			<meta name="msapplication-TileImage" content="/favicon/mstile-144x144.png">
#
# 			<!--css-->
# 			<link rel="stylesheet" href="/css/reset.css">
# 			<link rel="stylesheet" href="/css/base_new.css">
# 			<link rel="stylesheet" href="/css/common_new.css">
# 			<link rel="stylesheet" href="/css/font-awesome.min.css">
# 			<link rel="stylesheet" href="/css/font-icomoon.css">
# 			<!--css-->
#             <link rel="stylesheet" href="/css/club.css">
#             <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#   ga('create', 'UA-59064065-1', 'auto');
#   ga('require', 'GTM-M2DGXDD');
#   ga('require', 'linkid', 'linkid.js');
#   ga('send', 'pageview');
#
# </script>
# <script id="_lognos_script_">
# // begin edit block
# var _lognos = {params: {}, paramOrder: []};
#     _lognos.params.key1 = "";
#     _lognos.params.key2 = "";
#     _lognos.params.key3 = "";
#     _lognos.params.key4 = "";
#     _lognos.params.key5 = "";
#     _lognos.params.key6 = "";
#     _lognos.params.key7 = "";
#     _lognos.params.key8 = "";
#     _lognos.params.key9 = "";
#     _lognos.params.key10 = "";
#     // end edit block
#
#     // don't edit
#     _lognos.paramOrder = ["key1", "key2", "key3", "key4", "key5", "key6", "key7", "key8", "key9", "key10"];
#
# (function(a,b){
#     a.async = true; a.id = "_lognos_script_";
#     a.src = '//img.macromill.com/js/us000316tuw/5000002597-aa/lognos.js';
#     b.parentNode.insertBefore(a,b);
# }(document.createElement('script'),document.getElementsByTagName('script')[0]));
# </script>
#
# <!-- Yahoo!タグマネジャー -->
# <script id="tagjs" type="text/javascript">
#   (function () {
#     var tagjs = document.createElement("script");
#     var s = document.getElementsByTagName("script")[0];
#     tagjs.async = true;
#     tagjs.src = "//s.yjtag.jp/tag.js#site=4QkXqyh";
#     s.parentNode.insertBefore(tagjs, s);
#   }());
# </script>
# <noscript>
#   <iframe src="//b.yjtag.jp/iframe?c=4QkXqyh" width="1" height="1" frameborder="0" scrolling="no" marginheight="0" marginwidth="0"></iframe>
# </noscript>
# <!-- Yahoo!タグマネジャー -->
# <!-- ドコモタグ -->
# <!-- <script type="text/javascript">
#     var _dcmlinker = _dcmlinker || new Array();
#     var _paq = _paq || [];
#     _paq.push(["trackPageView"]);
#     var u="//s2.docomo-analytics.com/dcm/";
#     (function() {
#        _paq.push(['setTrackerUrl', u+'tr/dcmAn/img']);
#        _paq.push(['setSiteId', 125]);
#        _paq.push(["trackingType", 2]);
#        _paq.push(["afterAuthFlg", 1]);
#        var d=document, g=d.createElement("script"), s=d.getElementsByTagName("script")[0];
#        g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'js/union.js'; s.parentNode.insertBefore(g,s);
#       })();
# </script> -->
#
# <script type="text/javascript">
#   var _dcmlinker = _dcmlinker || [];
#   var _paq = _paq || [];
#   _paq.push(["trackPageView"]);
#   var u="//jf1.docomo-analytics.com/dcm/";
#   (function() {
#      _paq.push(["setTrackerUrl", u+"tr/dcmAn/img"]);
#      _paq.push(["setSiteId",125]);
#      _paq.push(["trackingType",3]);
#      _paq.push(["afterAuthFlg",1]);
#      var d=document, g=d.createElement("script"), s=d.getElementsByTagName("script")[0];
#      g.type='text/javascript'; g.async=true; g.defer=true;
#      g.src='//cdn.docomo-analytics.com/js/contents/union.js';
#      s.parentNode.insertBefore(g,s);
#     })();
# </script>
# <!-- ドコモタグ -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5W6LGTT');</script>
# <!-- End Google Tag Manager -->
#
#
# <!-- popinタグ -->
# <script type="text/javascript">
#     (function() {
#         var pa = document.createElement('script'); pa.type = 'text/javascript'; pa.charset = "utf-8"; pa.async = true;
#         pa.src = window.location.protocol + "//api.popin.cc/searchbox/j-league.js";
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(pa, s);
#     })();
#
# </script>
#
# <!-- popinタグ -->
#             <script type="text/javascript" charset="utf-8" src="https://map.yahooapis.jp/js/V1/jsapi?appid=dj0zaiZpPUhtaU9GME1GQUhsNyZzPWNvbnN1bWVyc2VjcmV0Jng9NDU-"></script>
#         </head>
#
#         <body class="club second">
#             <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/ja_JP/sdk.js#xfbml=1&version=v2.5&appId=1590035654547971";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-5W6LGTT"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#
# <div id="header">
# 	<div id="selectDivisitonArea">
# 		<div class="inner">
# 			<div id="selectDivision">
# 				<ul class="devisionLists">
# 					<li><a href="javascript:void(0);" id="topJ1Title" data-target="#j1Emb" class="current">Ｊ１</a></li>
# 					<li><a href="javascript:void(0);" id="topJ2Title" data-target="#j2Emb">Ｊ２</a></li>
# 					<li><a href="javascript:void(0);" id="topJ3Title" data-target="#j3Emb">Ｊ３</a></li>
# 				</ul>
# 			</div>
#
# 			<div class="embLists">
# 				<ul id="j1Emb" class="leagueBtn">
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'sapporo');" href="http://www.consadole-sapporo.jp/" target="_blank" title="北海道コンサドーレ札幌" class="embS embCon">北海道コンサドーレ札幌</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'sendai');" href="http://www.vegalta.co.jp/" target="_blank" title="ベガルタ仙台" class="embS embVeg">ベガルタ仙台</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'kashima');" href="http://www.so-net.ne.jp/antlers/" target="_blank" title="鹿島アントラーズ" class="embS embAnt">鹿島アントラーズ</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'urawa');" href="http://www.urawa-reds.co.jp/" target="_blank" title="浦和レッズ" class="embS embRed">浦和レッズ</a></li>
#
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'kashiwa');" href="http://www.reysol.co.jp/main.php" target="_blank" title="柏レイソル" class="embS embRey">柏レイソル</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'fctokyo');" href="https://www.fctokyo.co.jp/" target="_blank" title="ＦＣ東京" class="embS embFct">ＦＣ東京</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'kawasakif');" href="http://www.frontale.co.jp/" target="_blank" title="川崎フロンターレ" class="embS embFro">川崎フロンターレ</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'yokohamafm');" href="http://www.f-marinos.com/" target="_blank" title="横浜F・マリノス" class="embS embMar">横浜F・マリノス</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 
a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'gosaka23');" href="http://www.gamba-osaka.net/" target="_blank" title="ガンバ大阪Ｕ－２３" class="embS embGosaka23">ガンバ大阪Ｕ－２３</a></li>
# 					<li><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'cosaka23');" href="http://www.cerezo.co.jp/" target="_blank" title="セレッソ大阪Ｕ－２３" class="embS embCosaka23">セレッソ大阪Ｕ－２３</a></li>
# 				</ul>
# 			</div>
#
# 		</div>
# 	</div>
# 	<!--/#selectDivisitonArea-->
# 	<nav id="globalNavi">
# 		<div class="inner">
# 			<h2><a href="/" class="sample03Tit"><img src="/img/common/h1_logo03.png" alt="Ｊリーグ.jp（日本プロサッカーリーグ）"/></a></h2>
# 			<ul>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', '試合速報');" href="/game/" class="game">試合速報</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'チケット');" href="/ticket/" class="ticket">チケット</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'テレビ');" href="/tv/" class="tv">テレビ</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', '日程・結果');" href="/match/" class="match">日程・結果</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', '順位表');" href="/standings/" class="standings">順位表</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', '成績データ');" href="/stats/" class="stats">成績・データ</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'クラブ・選手');" href="/club/" class="club">クラブ・選手</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'About J');" href="/aboutj/" class="about">About Ｊ</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'ニュース');" href="/news/" class="news">ニュース</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'コラム');" href="/column/" class="column">コラム</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'フォト');" href="/photogallery/" class="photo">フォト</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', '動画');" href="/video/" class="video">動画</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', '大会・特集');" href="/special/" class="special" onclick="ga('send', 'event', 'globalNavi_pc', 'click', '大会・特集');">大会・特集</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'Jリーグの楽しみ方');" href="/j-tano/" class="guide">Ｊ<span>リーグの</span>楽<span>しみ方</span></a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', '初めてのJ');" href="/j-tano/?p=/article/index/tag/%E3%81%AF%E3%81%98%E3%82%81%E3%81%A6%E3%81%AE%EF%BC%AA" class="beginner"><img src="/img/common/icon_beginner.png" alt="初心者マーク">＃はじめてのＪ</a></li>
# 				<li><a onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ', 'プレスリリース');" href="/release/" class="release">プレスリリース</a></li>
# 			</ul>
# 		</div>
# 	</nav>
# </div>
# <!--/#header-->
# <div id="utilityArea">
# 	<div class="inner">
# 		<p id="gameLinkBTN">
# 			<a onclick="ga('send', 'event', 'TOPPAGE_pc', '今日の試合速報', '今日の試合速報');" href="/game/">今日の試合速報</a>
# 		</p>
# 		<div class="subNav">
# 			<ul>
# 				<li><a href="/en/" class="txtBtn" onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ下メニュー', 'English');">ENGLISH</a></li>
# 				<li><a href="/aboutj/academy/" class="txtBtn" onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ下メニュー', '2-アカデミー');">アカデミー</a></li>
# 				<li><a href="/release/hometown/" class="txtBtn" onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ下メニュー', 'ホームタウン活動');">ホームタウン活動</a></li>
# 				<li><a href="https://store.jleague.jp/" class="txtBtn onlineshop" onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ下メニュー', 'ショップ');">ショップ</a></li>
# 				<li><a href="/aboutj/100year.html" class="ico100years" onclick="ga('send', 'event', 'TOPPAGE_pc', 'Gナビ下メニュー', '百年構想');">J.LEAGUE百年構想</a></li>
# 			</ul>
# 		</div>
# 		<!--/.subNav-->
# 		<div class="searchArea">
# 			<form action="/search/">
# 				<input type="search" name="q" size="30" placeholder="" required="">
# 				<button type="submit" class="formBtn"><i class="fa fa-search"></i></button>
# 			</form>
# 		</div>
#
# 		<div class="snsIconNav">
# 			<ul>
# 			<li class="twitter"><a onclick="ga('send', 'event', 'headerPC_SNS', 'click', 'Twitter');" href="https://twitter.com/J_League" target="_blank">Twitter</a></li>
# 			<li class="facebook"><a onclick="ga('send', 'event', 'headerPC_SNS', 'click', 'FaceBook');" href="https://www.facebook.com/jleagueofficial" target="_blank">FaceBook</a></li>
# 			<li class="instagram"><a onclick="ga('send', 'event', 'headerPC_SNS', 'click', 'Instagram');" href="http://instagram.com/jleaguejp" target="_blank">Instagram</a></li>
# 			<li class="youTube"><a onclick="ga('send', 'event', 'headerPC_SNS', 'click', 'YouTube');" href="http://www.youtube.com/user/jleaguechannel" target="_blank">YouTube</a></li>
# 			<li class="line"><a onclick="ga('send', 'event', 'headerPC_SNS', 'click', 'LINE');" href="https://line.me/R/ti/p/%40j.league" target="_blank">LINE</a></li>
# 			</ul>
# 		</div>
#
# 	</div>
# </div>
# <!--/#utilityArea-->
#
#
#
# <style>
# .skyscraperWrap{
#     position: absolute;
#     top: 150px;
#     left: 50%;
# }
# .skyscraperWrap.leftside{
# 	margin-left: -730px;
# }
# .skyscraperWrap.rightside{
# 	margin-left: 560px;
# }
#
#
# /*///////////// FNJの時のみ以下のCSSを使用する*/
# /*body.indexTop{
# 	background: #100a0a url(/img/common/bg_fridaynightjleague.jpg) no-repeat top center;
# }*/
# /*body.indexTop .skyscraperWrap .otherpage{display: none;}
# body:not(.indexTop) .skyscraperWrap .toppage{display: none;}*/
#
# /*背景を黒のした時のトップページのもろもろ*/
# /*body.indexTop #jtano-accordion{background: #fff;}
# body.indexTop .hirachannel .textArea p,.hirachannel .textMore a{color:#fff;}
# body.indexTop .hirachannel .textMore a:after{border-color:#fff;}
# body.indexTop .matchInfo .tabList li a{background-color: rgba(255, 255, 255,0.7);}
# body.indexTop .matchInfo .tabList li.active a{background-color: #fff;}
# body.indexTop #utilityArea .inner #gameLinkBTN a,
# body.indexTop .subNav li a.txtBtn,
# body.indexTop .subNav li a.txtBtn.onlineshop{background: rgba(225,225,225,0.6);color: #000;}
# body.indexTop #utilityArea .searchArea{background: rgba(225,225,225,0.6);}
# body.indexTop .btmBnrLists li{margin-bottom: 1px; border: none;}
# body.indexTop .subNav li a.ico100years{background-color:rgba(225,225,225,0.6)}*/
# /*///////////// FNJの時のみ以上CSSを使用する*/
#
# body.openingGame .skyscraperWrap,
# body.afc .skyscraperWrap,
# body.leaguecup .skyscraperWrap,
# body.u14 .skyscraperWrap,
# body.u16_cl .skyscraperWrap,
# body.gothia .skyscraperWrap,
# body.satellite .skyscraperWrap,
# body.jleagueking .skyscraperWrap,
# body.kumamoto .skyscraperWrap,
# body.emperor .skyscraperWrap,
# body.jyouth .skyscraperWrap,
# body.samuraiblue .skyscraperWrap,
# body.jsgoal .skyscraperWrap,
# body.suruga2016 .skyscraperWrap,
# body.cwc .skyscraperWrap{display: none;}
# </style>
#
# <!--
#
# （注）スカイスクレイパーを表示するときは「favicon.html」の13行目、16行目あたりを都度入れ替えしてください！！！！一緒に公開してね！！
#
#  -->
#
#
# <!-- 左　////////////////////// -->
#
# <div class="skyscraperWrap leftside">
# <a href="https://www.jleague.jp/match/search/j1/latest/" onclick="ga('send', 'event', 'pc_skyscraper', 'click', 'J1再開');">
# <img src="/img/skyscraper/skyscraper_left_20180706.png" alt="J1再開">
# </a>
#
#
# <!-- ルヴァンカップ左 -->
#
# <!--
#
#
# <a href="https://www.jleague.jp/leaguecup/2018/match/" onclick="ga('send', 'event', 'pc_skyscraper', 'click', 'ＪリーグYBCルヴァンカップ　プレーオフステージ 第1戦');">
# <img class="toppage" src="/img/skyscraper/skyscraper_leaguecup_left_180530.png" alt="ＪリーグYBCルヴァンカップ　プレーオフステージ 第1戦">
# <img class="otherpage" src="/img/skyscraper/skyscraper_fnj-otherpage_left.png" alt="明治安田生命Ｊリーグ フライデーナイトＪリーグ">-->
#
#
#
# </div>
#
#
# <!-- 右　////////////////////// -->
#
#
# <div class="skyscraperWrap rightside">
# <a href="https://www.jleague.jp/match/search/j1/latest/" onclick="ga('send', 'event', 'pc_skyscraper', 'click', 'J1再開');">
# <img src="/img/skyscraper/skyscraper_right_20180706.png" alt="J1再開">
#
#
# <!-- ルヴァンカップ左 -->
#
# <!--
#
# <div class="skyscraperWrap rightside">
# <a href="https://www.jleague.jp/leaguecup/2018/match/" onclick="ga('send', 'event', 'pc_skyscraper', 'click', 'ＪリーグYBCルヴァンカップ　プレーオフステージ 第2戦);">
# <img class="toppage" src="/img/skyscraper/skyscraper_leaguecup_right_180530.png" alt="ＪリーグYBCルヴァンカップ　プレーオフステージ 第2戦">
# <img class="otherpage" src="/img/skyscraper/skyscraper_fnj-otherpage_left.png" alt="明治安田生命Ｊリーグ フライデーナイトＪリーグ">-->
# </a>
#
# </div>
#
#
#
# <div class="matchInfo">
# 	<ul class="tabList">
#
#
#
#
# 		<li class="active"><a data-id="j1" href="javascript:void(0);" class="btnJ1" onclick="ga('send', 'event', 'TOPPAGE_pc', 'スコアモジュールタブ', 'J1');"><i>明治安田生命Ｊ１リーグ</i></a></li>
# 		<li><a data-id="acl" href="javascript:void(0);" class="btnAcl" onclick="ga('send', 'event', 'TOPPAGE_pc', 'スコアモジュールタブ', 'ACL');"><i>ＡＦＣ チャンピオンズリーグ</i></a></li>
#     	<li><a data-id="ylc" href="javascript:void(0);" class="btnYLC" onclick="ga('send', 'event', 'TOPPAGE_pc', 'スコアモジュールタブ', 'ルヴァン');"><i>２０１７ＪリーグYBCルヴァンカップ</i></a></li>
#       <li><a data-id="emperor" href="javascript:void(0);" class="btnEmperorscup" onclick="ga('send', 'event', 'TOPPAGE_pc', 'スコアモジュールタブ', '天皇杯');"><i>天皇杯</i></a></li>
#     	<li><a data-id="j2" href="javascript:void(0);" class="btnJ2" onclick="ga('send', 'event', 'TOPPAGE_pc', 'スコアモジュールタブ', 'J2');"><i>明治安田生命Ｊ２リーグ</i></a></li>
# 		<li><a data-id="j3" href="javascript:void(0);" class="btnJ3" onclick="ga('send', 'event', 'TOPPAGE_pc', 'スコアモジュールタブ', 'J3');"><i>明治安田生命Ｊ３リーグ</i></a></li>
#
# 		<li><a data-id="japan" href="javascript:void(0);" class="btnJapan" onclick="ga('send', 'event', 'TOPPAGE_pc', 'スコアモジュールタブ', '日本代表');"><i>日本代表</i></a></li>
#
#
#     	<!--
#
# <li><a data-id="asiachallenge" href="javascript:void(0);" class="btnAsiaChallenge" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'asiachallenge2018');"><i>Ｊリーグ　アジアチャレンジinインドネシア インターリーグカップ</i></a></li>
#
# <li><a data-id="postseason" href="javascript:void(0);" class="btnPostSeason" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'postseason');"><i>Ｊ１昇格プレーオフ</i></a></li> -->
#
# 		<!-- <li><a data-id="u23_asia" href="javascript:void(0);" class="btnU23_asia" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'u23_asia');"><i>AFC U-23選手権</i></a></li> -->
#
# 		<!-- <li><a data-id="international_youth" href="javascript:void(0);" class="btnInternational-youth" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'international-youth');"><i>２０１７インターナショナルユースカップ</i></a></li> -->
# 		<!--<li><a data-id="asiachallenge" href="javascript:void(0);" class="btnAsiaChallenge" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'asiachallenge2017');"><i>Ｊリーグ　アジアチャレンジinタイ インターリーグカップ</i></a></li>-->
# 		<!-- <li><a data-id="suruga" href="javascript:void(0);" class="btnSbc" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'suruga2016');"><i>スルガ銀行 チャンピオンシップ</i></a></li> -->
#
# 		<!-- <li><a data-id="jyouth" href="javascript:void(0);" class="btnJyouth" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'jyouth2016');"><i>Ｊユースカップ</i></a></li> -->
# 		<!-- <li><a data-id="fcwc" href="javascript:void(0);" class="btnCwc"         onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'cwc2016');"><i>FIFAクラブワールドカップ</i></a></li> -->
# 		<!-- <li><a data-id="jwc" href="javascript:void(0);" class="btnJWC" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'jwc2017');"><i>ＪＷＣ２０１７</i></a></li> -->
# 		<!-- <li><a data-id="eaff_e1" href="javascript:void(0);" class="btnE1" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'E-1');"><i>E-1</i></a></li> -->
#
# 		<!-- <li><a data-id="u17_wc" href="javascript:void(0);" class="btnu17_wc" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'u17_wc');"><i>U-17日本代表</i></a></li> -->
# 		<!--
# 			<li><a data-id="international-u20" href="javascript:void(0);" class="btnU20" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'empr2017');"><i>U-20日本代表</i></a></li>
#
#
#
# 		<li><a data-id="nyc" href="javascript:void(0);" class="btnDAZN" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'nyc2017');"><i>DAZNニューイヤーカップ</i></a></li>
#
# 		<li><a data-id="j1" href="javascript:void(0);" class="btnJ1" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'J1');"><i>明治安田生命Ｊ１リーグ</i></a></li>
#
#
# 		<li><a data-id="ylc" href="javascript:void(0);" class="btnYLC" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'YLC');"><i>２０１６ＪリーグYBCルヴァンカップ</i></a></li>
#
# 		<li><a data-id="j3" href="javascript:void(0);" class="btnJ3" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'J3');"><i>明治安田生命Ｊ３リーグ</i></a></li>
#
#
#
#
#
# -->
#
# 		<!-- <li><a data-id="u23" href="javascript:void(0);" class="btnU23" onclick="ga('send', 'event', 'SC-MODULE-CAT_pc_jp', 'click', 'U-23_2016');"><i>U-23日本代表</i></a></li> -->
# 	</ul>
# 	<div class="tabContentWrap">
# 	<div class="tabContent" style="height: 98px;"><p class="scoreload"><img src="/img/common/loader.gif"></p></div>
# 	</div>
# </div>
# <!-- /#matchInfo -->
#
#
#
# <!-- ///// アラート表示（クラスに「alert」を追加） /////  -->
#
#
#
#
#
#
#
# <!--
#
# ■リンクあり
#
# <div class="tickerwrap alert">
# <a href="●">明治安田Ｊ● 第●節 ●vs●は●のため●</a>
# </div>
#
# ■リンクなし
# -->
# <!--
# <div class="tickerwrap alert">
# <span>ＪリーグYBCルヴァンカップ　グループステージ　第5節 鳥栖vs長崎は回線トラブルによりデータ配信が遅延しております。復旧まで今しばらくお待ちください。</span>
#
# </div>
#
#
#
# ■原因
#
# 荒天
# 雷雨
# 地震
# 激しい雨
# ピッチコンディション不良
#
# ■状況
#
# キックオフ時間が遅延しております。
# 試合が中断しております。
# 試合中止となりました。代替日程は決定次第発表いたします。
# 開催延期となりました。代替日程は決定次第発表いたします。
#
# -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
#
#
# <div class="tickerwrap alert">
# <a href="https://www.youtube.com/user/jleaguechannel">システムトラブルによりＪリーグインターナショナルユースカップのデータが正常に表示できておりません。<br>Ｊリーグ公式YouTubeチャンネルにてLIVE配信を行っております。こちらをご覧ください。</a>
# </div>
#
#
#  <div class="tickerwrap alert">
# <span>
# 【お知らせ】台風の影響により以下の試合の開催中止が決定しております。<br>（<a href="https://www.jleague.jp/news/article/10161/" target="_blank" onclick="ga('send', 'event', 'info_pc1', 'click', 'C大阪中止');">明治安田Ｊ３ 第23節 Ｃ大23vs北九州</a>／<a href="https://www.jleague.jp/news/article/10163/" target="_blank" onclick="ga('send', 'event', '_info_pc2', 'click', '愛媛中止');">明治安田Ｊ２ 第33節 愛媛vs京都</a>）</span>
# </div>
#
#
#
#  <div class="tickerwrap alert">
# <span>
# 2/26に開催した試合におけるDAZNでの配信に問題が発生しました。ご不便とご迷惑をお掛けしましたことを深くお詫び申し上げます。現在、ライブ配信に不具合のあったＧ大阪vs甲府、愛媛vs金沢の試合についてはＪリーグ公式YouTubeチャンネルにてフルマッチの試合映像をご視聴いただけます。
# <br>Ｇ大阪vs甲府（<a href="https://youtu.be/qcv17VfGDhA" target="_blank" onclick="ga('send', 'event', 'tickerLink_j1_01', 'click', 'YouTubeフルマッチ試合映像_0226Ｇ大阪vs甲府_前半');">前半</a>・<a href="https://youtu.be/wzrRjVbtxF8" target="_blank" onclick="ga('send', 'event', 'tickerLink_j1_01', 'click', 'YouTubeフルマッチ試合映像_0226Ｇ大阪vs甲府_後半');" onclick="ga('send', 'event', 'tickerLink_j2_01', 'click', 'YouTubeフルマッチ試合映像_0226愛媛vs金沢_前半');">後半</a>）／愛媛vs金沢（<a href="https://youtu.be/3aTgGrX5mPQ" target="_blank" onclick="ga('send', 'event', 'tickerLink_j2_01', 'click', 'YouTubeフルマッチ試合映像_0226愛媛vs金沢_前半');">前半</a>・<a href="https://youtu.be/vrCm--K3vL4" target="_blank" onclick="ga('send', 'event', 'tickerLink_j2_01', 'click', 'YouTubeフルマッチ試合映像_0226愛媛vs金沢_後半');">後半</a>）<a href="http://media.dazn.com/ja/press-releases-ja/2017/02/271230/" target="_blank" onclick="ga('send', 'event', 'dazn_info_pc', 'click', 'DAZNからのお知らせ');">DAZNからのお知らせ</a></span>
# </div>
# -->
#
#
# <!--<div class="tickerwrap">
# <span>
# システムトラブルにより明治安田生命Ｊ１リーグ 第1節のデータが正常に表示できておりません。<br>現在復旧に向けて作業を進めておりますので、今しばらくお待ちください
# </span>
# </div>-->
#
#
#
# <!--
#
#
#  <div class="tickerwrap">
# <span>
# [INSERT MATCHES]へアクセスできない状況が続き、お客様にご不便とご迷惑をお掛けしましたことを深くお詫び申し上げます。<br>今後同様の問題が発生しないようにＪリーグとDAZNは更なる改善に取り組んでまいります。
# </span>
# </div>
#
#  <div class="tickerwrap">
# <span>
# [INSERT MATCHES]へアクセスできない状況が続き、お客様にご不便とご迷惑をお掛けしましたことを深くお詫び申し上げます。<br>ファンの皆さまにＪリーグをお届けできない時間が続いてしまい、大変申し訳ありませんでした。<br>[INSERT ISSUE]はすでに解決しており、今後同様の問題が発生しないようにＪリーグとDAZNは更なる改善に取り組んでまいります。
# </span>
# </div>
#
#
#
#  <div class="tickerwrap">
# <span>Ｊリーグチケットは一時的なアクセス増加により混雑しており、接続しづらい状態となっております。<br>再度時間をおいてアクセスをお願いいたします</span>
# </div>
#
# <div class="tickerwrap alert">
# <a href="/news/article/7104/" onclick="ga('send', 'event', 'pc_ticker_red', 'click', 'ルヴァンカップ 準決勝 第1戦 Ｇ大阪vs横浜FMは台風の影響により、試合中止となりました。');">
# ルヴァンカップ 準決勝 第1戦 Ｇ大阪vs横浜FMは台風の影響により、試合中止となりました。
# </a>
# </div>
#
#
#
# <div class="tickerwrap alert">
# <a href="/news/article/6703/" onclick="ga('send', 'event', 'pc_ticker_red', 'click', '明治安田Ｊ２ 第29節 Ｃ大阪vs松本は雷雨の影響により、キックオフ時間が19:45に変更となりました。');">
# 明治安田Ｊ２ 第29節 Ｃ大阪vs松本は雷雨の影響により、キックオフ時間が19:45に変更となりました。
# </a>
# </div>
#
# <div class="tickerwrap alert">
# <span>システムトラブルにより明治安田生命Ｊ１リーグ 1stステージ第16節のデータが正常に表示できておりませんでしたが、復旧いたしました。<br>ご迷惑をおかけしたことをお詫び申し上げます</span>
# </div>
#
#
# <div class="tickerwrap alert">
# <a href="/news/article/6091/" onclick="ga('send', 'event', 'pc_ticker_red', 'click', '「システムトラブルにより明治安田生命Ｊ１リーグ 1stステージ第15節のデータが正常に表示できておりませんでしたが、復旧いたしました');">
# システムトラブルとアクセス集中に伴う表示不具合について
# </a>
# </div>
#
#
# <div class="tickerwrap alert">
# <a href="/news/article/6319/" onclick="ga('send', 'event', 'pc_ticker_red', 'click', '明治安田Ｊ２ 第21節 北九州vs東京Ｖは雷雨の影響により、キックオフ時間が18:30に変更となりました。');">
# 明治安田Ｊ２ 第21節 北九州vs東京Ｖは雷雨の影響により、キックオフ時間が18:30に変更となりました。
# </a>
# </div>
#
#
#
#
# <div class="tickerwrap alert">
# <a href="/special/postponed_match/2016/" onclick="ga('send', 'event', 'pc_ticker_red', 'click', '「平成２８年熊本地震」および暴風の影響で中止となった試合');">
# システムトラブルにより明治安田生命Ｊ１リーグ 1stステージ第15節のデータが正常に表示できておりません。<br>現在復旧に向けて作業を進めておりますので、今しばらくお待ちください
# </a>
# </div>
# -->
#
# <!--
# <div class="tickerwrap alert">
# <a href="/special/postponed_match/2016/" onclick="ga('send', 'event', 'pc_ticker_red', 'click', '「平成２８年熊本地震」および暴風の影響で中止となった試合');">
# 「平成２８年熊本地震」および暴風の影響で中止となった試合
# </a>
# </div>
# -->
#
# <!-- ///// 通常表示 /////  -->
# <!-- <div class="tickerwrap">
# <a href="/playoff2015/standings.html" onclick="ga('send', 'event', 'pc_ticker', 'click', '1');">
# 【明治安田Ｊ２ 第42節】自動昇格・昇格プレーオ出場争い 順位表をおさらい！
# </a>
# </div> -->
# <!--
# <div class="tickerwrap">
# <span>システムトラブルにより明治安田生命Ｊ１リーグ 1stステージ第15節のデータが正常に表示できておりません。<br>現在復旧に向けて作業を進めておりますので、今しばらくお待ちください</span>
# </div>
# -->
#
# <!-- ///// 通常表示（リンクなし：aタグの代わりにspanタグ） /////  -->
# <!-- <div class="tickerwrap">
# <span>Ｊリーグチケットは一時的なアクセス増加により混雑しており、接続しづらい状態となっております。<br>再度時間をおいてアクセスをお願いいたします</span>
# </div> -->
#
#
#
# <!--
#
# <div class="tickerwrap">
# Ｊリーグチケットは一時的なアクセス増加により混雑しており、接続しづらい状態となっております。再度時間をおいてアクセスをお願いいたします
# </div>
#
#
# <div class="tickerwrap">
# <a href="/playoff2015/standings.html" onclick="ga('send', 'event', 'pc_ticker', 'click', '1');">【明治安田Ｊ２ 第42節】自動昇格・昇格プレーオ出場争い 順位表をおさらい！</a>
# </div>
#
#
#
#   -->
#
#
#             <div class="content">
#                 <div class="main">
#                     <section class="clubArea">
# <nav id="breadcrumbList" class="clearfix">
#   <ol>
#   <li class="home" itemscope="itemscope" itemtype="http://data-vocabulary.org/Breadcrumb"><a itemprop="url" href="/"><span itemprop="title">Ｊリーグ TOP</span></a></li>
#   <li itemscope="itemscope" itemtype="http://data-vocabulary.org/Breadcrumb"><a itemprop="url" href="/club/"><span itemprop="title">クラブ一覧</span></a></li>
#   <li class="current"><h1>北海道コンサドーレ札幌 日程・結果</h1></li>
#   </ol>
# </nav>
#                         <div class="secondPageTitl">
#                             <h2>クラブ・選手名鑑</h2>
#                         </div>
#                         <!--/.secondPageTitl-->
# 							<ul class="snsBtn clearfix">
# 								<li class="btnHatena">
# 									<a href="http://b.hatena.ne.jp/entry/" class="hatena-bookmark-button" data-hatena-bookmark-layout="simple" title="このエントリーをはてなブックマークに追加"><img src="https://b.st-hatena.com/images/entry-button/button-only@2x.png" alt="このエントリーをはてなブックマークに追加" width="20" height="20" style="border: none;" /></a><script type="text/javascript" src="https://b.st-hatena.com/js/bookmark_button.js" charset="utf-8" async="async"></script>
# 								</li>
# 								<li class="btnFacebook">
# 									<div class="fb-like" data-layout="button_count" data-action="like" data-show-faces="false" data-share="true"></div>
# 								</li>
# 								<li class="btnTwitter">
# 									<a href="https://twitter.com/share" class="twitter-share-button" data-hashtags="Ｊリーグ">Tweet</a>
# 									<script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script>
# 								</li>
# 							</ul>
#                         <section class="clubNameArea clubTop">
#                             <div class="clubTeamTitle clubJ1Emb clearfix">
#                                 <h3><span class="embM2 embSapporo">北海道コンサドーレ札幌</span>北海道コンサドーレ札幌</h3>
#                                 <span class="Logo"></span>
#                                 <div class="formArea formNoBoder">
#                                     <form>
#                                         <ul>
#                                             <li class="select club">
#                                                 <select name="clubName">
#                                                     <option value="">クラブ名</option>
# <optgroup label="Ｊ１クラブ">
#     <option value="sapporo" id="club-1-0">北海道コンサドーレ札幌</option>
#     <option value="sendai" id="club-1-1">ベガルタ仙台</option>
#     <option value="kashima" id="club-1-2">鹿島アントラーズ</option>
#     <option value="urawa" id="club-1-3">浦和レッズ</option>
#     <option value="kashiwa" id="club-1-4">柏レイソル</option>
#     <option value="ftokyo" id="club-1-5">FC東京</option>
#     <option value="kawasakif" id="club-1-6">川崎フロンターレ</option>
#     <option value="yokohamafm" id="club-1-7">横浜F・マリノス</option>
#     <option value="shonan" id="club-1-8">湘南ベルマーレ</option>
#     <option value="shimizu" id="club-1-9">清水エスパルス</option>
#     <option value="iwata" id="club-1-10">ジュビロ磐田</option>
#     <option value="nagoya" id="club-1-11">名古屋グランパス</option>
#     <option value="gosaka" id="club-1-12">ガンバ大阪</option>
#     <option value="cosaka" id="club-1-13">セレッソ大阪</option>
#     <option value="kobe" id="club-1-14">ヴィッセル神戸</option>
#     <option value="hiroshima" id="club-1-15">サンフレッチェ広島</option>
#     <option value="tosu" id="club-1-16">サガン鳥栖</option>
#     <option value="nagasaki" id="club-1-17">V・ファーレン長崎</option>
# </optgroup>
# <optgroup label="Ｊ２クラブ">
#     <option value="yamagata" id="club-2-0">モンテディオ山形</option>
#     <option value="mito" id="club-2-1">水戸ホーリーホック</option>
#     <option value="tochigi" id="club-2-2">栃木SC</option>
#     <option value="omiya" id="club-2-3">大宮アルディージャ</option>
#     <option value="chiba" id="club-2-4">ジェフユナイテッド千葉</option>
#     <option value="tokyov" id="club-2-5">東京ヴェルディ</option>
#     <option value="machida" id="club-2-6">FC町田ゼルビア</option>
#     <option value="yokohamafc" id="club-2-7">横浜FC</option>
#     <option value="kofu" id="club-2-8">ヴァンフォーレ甲府</option>
#     <option value="matsumoto" id="club-2-9">松本山雅FC</option>
#     <option value="niigata" id="club-2-10">アルビレックス新潟</option>
#     <option value="kanazawa" id="club-2-11">ツエーゲン金沢</option>
#     <option value="gifu" id="club-2-12">FC岐阜</option>
#     <option value="kyoto" id="club-2-13">京都サンガF.C.</option>
#     <option value="okayama" id="club-2-14">ファジアーノ岡山</option>
#     <option value="yamaguchi" id="club-2-15">レノファ山口FC</option>
#     <option value="sanuki" id="club-2-16">カマタマーレ讃岐</option>
#     <option value="tokushima" id="club-2-17">徳島ヴォルティス</option>
#     <option value="ehime" id="club-2-18">愛媛FC</option>
#     <option value="fukuoka" id="club-2-19">アビスパ福岡</option>
#     <option value="kumamoto" id="club-2-20">ロアッソ熊本</option>
#     <option value="oita" id="club-2-21">大分トリニータ</option>
# </optgroup>
# <optgroup label="Ｊ３クラブ">
#     <option value="morioka" id="club-3-0">グルージャ盛岡</option>
#     <option value="akita" id="club-3-1">ブラウブリッツ秋田</option>
#     <option value="fukushima" id="club-3-2">福島ユナイテッドFC</option>
#     <option value="kusatsu" id="club-3-3">ザスパクサツ群馬</option>
#     <option value="ysyokohama" id="club-3-4">Y.S.C.C.横浜</option>
#     <option value="sagamihara" id="club-3-5">SC相模原</option>
#     <option value="nagano" id="club-3-6">AC長野パルセイロ</option>
#     <option value="toyama" id="club-3-7">カターレ富山</option>
#     <option value="fujieda" id="club-3-8">藤枝MYFC</option>
#     <option value="numazu" id="club-3-9">アスルクラロ沼津</option>
#     <option value="tottori" id="club-3-10">ガイナーレ鳥取</option>
#     <option value="kitakyushu" id="club-3-11">ギラヴァンツ北九州</option>
#     <option value="kagoshima" id="club-3-12">鹿児島ユナイテッドFC</option>
#     <option value="ryukyu" id="club-3-13">FC琉球</option>
#     <option value="ftokyo_u23" id="club-3-14">FC東京U-23</option>
#     <option value="gamba_u23" id="club-3-15">ガンバ大阪U-23</option>
#     <option value="cosaka_u23" id="club-3-16">セレッソ大阪U-23</option>
# </optgroup>                                                </select>
#                                             </li>
#                                         </ul>
#                                     </form>
#                                 </div>
#                                 <!-- /.formArea -->
#                             </div>
#                             <!--/.clubTeamTitle-->
#
#                             <div class="clubRankNextGame" style="display:none">
#                                 <p class="komeRight12">更新日：2018年5月20日(日) 20:01</p>
#                                 <table class="rankingTable j1table">
#                                     <tr>
#                                         <th rowspan="3">明治安田生命<br>Ｊ１リーグ</th>
#                                         <th class="stg">１stステージ</th>
#                                         <td><span>-</span>勝<span>-</span>分<span>-</span>敗</td>
#                                         <td>勝点<span>-</span></td>
#                                         <td><span>-</span>位</td>
#                                     </tr>
#                                     <tr>
#                                         <th class="stg">２ndステージ</th>
#                                         <td><span>-</span>勝<span>-</span>分<span>-</span>敗</td>
#                                         <td>勝点<span>-</span></td>
#                                         <td><span>-</span>位</td>
#                                     </tr>
#                                     <tr>
#                                         <th class="stg">年間</th>
#                                         <td><span>7</span>勝<span>5</span>分<span>3</span>敗</td>
#                                         <td>勝点<span>26</span></td>
#                                         <td><span>5</span>位</td>
#                                     </tr>
#                                 </table>
#                                 <p class="rightMorelLink"><a href="/standings/j1/">明治安田生命Ｊ１リーグの順位表はこちら</a></p>
#                             </div>
#                             <!--/.clubRankNextGame-->
#
#                             <section class="nextGameTableArea">
#                                 <div class="ttlLink">
#                                     <h4 class="blockTit">今後3試合の予定</h4>
#                                                                     </div>
#                                 <table class="dataTable">
#                                     <thead class="bgGray">
#                                         <tr>
#                                             <td class="date">年月日</td>
#                                             <td class="time">開始時刻</td>
#                                             <td class="opp">対戦相手</td>
#                                             <td class="stadium">スタジアム</td>
#                                             <td class="league">大会名</td>
#                                             <td class="ticket">チケット</td>
#                                             <td class="tv">テレビ放送</td>
a></dd>
# 					<dd><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'gosaka23');" href="http://www.gamba-osaka.net/" target="_blank" title="ガンバ大阪Ｕ－２３" class="embGosaka23">ガンバ大阪Ｕ－２３</a></dd>
# 					<dd><a onclick="ga('send', 'event', 'CLUBLINK_pc', 'click', 'cosaka23');" href="http://www.cerezo.co.jp/" target="_blank" title="セレッソ大阪Ｕ－２３" class="embCosaka23">セレッソ大阪Ｕ－２３</a></dd>
# 					</dl>
# 					<!-- /.j3List -->
# 				</div>
# 				<!-- /#clubArea -->
# 				<nav id="footerNav">
# 					<div class="ttlArea">
# 						<!-- <h2>J.LEAGUE</h2> -->
# 					</div>
# 					<div id="listArea">
# 						<div>
# 							<dl>
# 								<dt><a href="/ticket/">チケット</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 							<dl>
# 								<dt><a href="/tv/">テレビ放送</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 						</div>
# 						<div>
# 							<dl>
# 								<dt><a href="/news/">ニュース</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 							<dl>
# 								<dt><a href="/match/">日程・結果</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 						</div>
# 						<div>
# 							<dl>
# 								<dt><a href="/standings/">順位表</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 							<dl>
# 								<dt><a href="/stats/">成績・データ</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 						</div>
# 						<div>
# 							<dl>
# 								<dt><a href="/club/">クラブ・選手</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 							<dl>
# 								<dt><a href="/video/">動画</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 						</div>
# 						<div>
# 							<dl>
# 								<dt><a href="/photo/">フォト</a></dt>
# 								<dd><a href="#" target="_blank"></a></dd>
# 							</dl>
# 							<dl>
# 								<dt><a href="/column/">コラム</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 						</div>
# 						<div>
# 							<dl>
# 								<dt><a href="/guide/hajimetej/">サッカー観戦ガイド</a></dt>
# 								<!--
# 								<dd><a href="#" target="_blank"></a></dd>
# 								-->
# 							</dl>
# 						</div>
# 					</div>
# 				</nav>
# 				<!-- /#footerNav -->
#
# 				<div id="bottomArea">
# 					<ul>
# 						<li><a href="https://login.jleague.jp/contents/privacypolicy.html" target="_blank">プライバシーポリシー</a></li>
# 						<li><a href="/general/kiyaku.html">利用規約</a></li>
# 						<li><a href="/general/copyright.html">著作権について</a></li>
# 						<li><a href="https://www.jleague.jp/form/support/faq.html">お問い合わせ</a></li>
# 						<li><a href="/release/">プレスリリース</a></li>
# 						<li><a href="https://jmc.j-league.or.jp/media/" target="_blank">メディアチャンネル</a></li>
# 					</ul>
# 					<p>本サイト（<a href="https://www.jleague.jp/">Ｊリーグ.jp[日本プロサッカーリーグ]</a>）で使用している文章・画像等の無断での複製・転載を禁止します。<br>&copy; 公益社団法人 日本プロサッカーリーグ（Ｊリーグ）　J.LEAGUE Digital Inc.　J.LEAGUE MARKETING INC.　J.LEAGUE MEDIA PROMOTION INC.　PIA Corporation.ALL RIGHTS RESERVED.</p>
# 				</div>
# 				<!-- /#bottomArea -->
#
#             <a href="#" id="pageTop" onclick="ga('send', 'event', 'PAGETOP_pc', 'click', 'ページの先頭へ');"><img src="/img/common/ico_pagetop.png" width="40" height="40" alt="ページの先頭へ"></a>
#
#
# 			</footer>
#
#             <!--js-->
# 			<script src="/js/jquery-1.11.1.min.js"></script>
# 			<script src="/js/jquery.bxslider.js"></script>
# 			<script src="/js/jquery.cookie.js"></script>
# 			<script src="/js/spSwitcher.js"></script>
# 			<script src="/js/shuffule.js"></script>
# 			<script src="/js/util.js"></script>
# 			<script src="/js/matchinfo_slider.js"></script>
# 			<script src="/js/tenmetsu.js"></script>
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script>
#             <script type="text/javascript">
#                 $(document).ready(function(){
#                     $('ul.tabListTxt li a').click(function(){
#                         $('ul.tabListTxt li').removeClass('active');
#                         socialLoad($(this).attr('href'));
#                     });
#                     socialLoad( document.location.hash ? document.location.hash : '#day' );
#
#                     $('select[name=clubName]').change(function(){
#                         var s = $(this).val();
#                         if ( s ) {
#                             location.href = '/club/'+s+'/day/';
#                         }
#                     });
#                 });
#
#                 // タブ切り換え処理
#                 var socialLoad = function( hash ) {
#                     if ( !hash ) return;
#                     $('ul.tabListTxt li').removeClass('active');
#                     var controller = hash.replace('#','ajax_');
#                     var url = '/club/sapporo/';
#                     url += controller;
#                     var d = $('div#loadArea');
#                     $.ajax({
#                         type: "GET",
#                         url: url,
#                         cache: false,
#                         data: "callingTeamId=276"
#                     }).success(function(data){
#                         $('ul.tabListTxt li a[href="'+hash+'"]').parent().addClass('active');
#                         d.html('').hide().html(data).fadeIn();
#                     });
#                 }
#             </script>
#             <script type="text/javascript">
#                 // search-click prev-month next-month linkclick
#                 $(function() {
#                     $(document).on('click', '#day_s_btn', function() {
#                         monthMoveSource('search');
#                         return false;
#                     });
#                     $(document).on('click', '#prev_link', function() {
#                         var w_kye = 'prev_month';
#                         monthMoveSource(w_kye);
#                         return false;
#                     });
#                     $(document).on('click', '#next_link', function() {
#                         var w_kye = 'next_month';
#                         monthMoveSource(w_kye);
#                         return false;
#                     });
#                     $(document).on('click', '#prev_link2', function() {
#                         var w_kye = 'prev_month';
#                         monthMoveSource(w_kye);
#                         return false;
#                     });
#                     $(document).on('click', '#next_link2', function() {
#                         var w_kye = 'next_month';
#                         monthMoveSource(w_kye);
#                         return false;
#                     });
#                 });
#                 // day month moving
#                 function monthMoveSource(key) {
#                     if(key == 'search'){
#                         var year  = $("#day_year" ).val();
#                         var month = $("#day_month").val();
#                         var keymonth = month;    // optionのselected用
#                         if(month == '13'){
#                             var year  = Number(year) + 1;
#                             var month = '1';
#                         }
#                     }else{
#                         var year  = $('#h_year' ).text();
#                         var month = $('#h_month').text();
#                     }
#                     var d = $('div#loadArea');
#                     var w_kye = key;
#                     var w_url = "/club/sapporo/ajax_day_month";
#                     $.ajax({
#                          url: w_url
#                         ,type: "GET"
#                         ,cache: false
#                         ,dataType: "html"
#                         ,data: {
#                              month_key : key
#                             ,year : year
#                             ,month : month
#                             ,keymonth : keymonth
#                         }
#                         ,success: function(data, textStatus){
#                             // 成功 - imageタグの書き換え
#                             //alert('Success');
#                             $('ul.tabListTxt li a[href="#day"]').parent().addClass('active');
#                             d.html('').hide().html(data).fadeIn();
#                         }
#                         ,error: function(XMLHttpRequest, textStatus, errorThrown) {
#                         }
#                     });
#                     return false;
#                 }
#             </script>
#             <script type="text/javascript">
#                 // day month moving
#                 function result_year_move() {
#                     var year  = $("#result_year").val();
#                     var d = $('div#loadArea');
#                     var w_url = "/club/sapporo/ajax_result";
#                     $.ajax({
#                          url: w_url
#                         ,type: "GET"
#                         ,cache: false
#                         ,dataType: "html"
#                         ,data: {
#                              result_year : year
#                         }
#                         ,success: function(data, textStatus){
#                             $('ul.tabListTxt li a[href="#result"]').parent().addClass('active');
#                             d.html('').hide().html(data).fadeIn();
#                         }
#                         ,error: function(XMLHttpRequest, textStatus, errorThrown) {
#                         }
#                     });
#                     return false;
#                 }
#             </script>
#         </body>
#     </html>

# %%
import requests
from bs4 import BeautifulSoup

request = requests.get("https://www.jleague.jp/club/sapporo/day/#profile")
print(request.status_code)
request.raise_for_status
soup = BeautifulSoup(request.text) # HTMLのパース

td = soup.find("td", {"class":"cellTwo"}) # HTMLのタグとクラスを指定して取り出し

for p in td.findAll("p"): # articleタグの取り出し
    print("タイトル:", p.find("p", {"class":"leftTxt"}).get_text()) # タイトルの取り出し
    print("概要:", p.find("p", {"class":"rightTxt"}).get_text()) # 概要の取り出し

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://www.jleague.jp/club/sapporo/day/#profile")
bsObj = BeautifulSoup(html, "html.parser")
table = bsObj.findAll("table",{"class":"dataTable.profTable2"})
print(table.findAll("tr"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-738da35a497d> in <module>()
#       4 bsObj = BeautifulSoup(html, "html.parser")
#       5 table = bsObj.findAll("table",{"class":"dataTable.profTable2"})
# ----> 6 print(table.find("tr"))
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

request = urlopen("https://www.jleague.jp/club/sapporo/day/#profile")
soup = BeautifulSoup(request,"html.parser")
table = soup.find_all("table", {"class": "dataTable profTable2"})
trs = table.find_all("tr")
for tr in trs:
    print("タイトル:", tr.find_all("p", {"class":"rightTxt"}).get_text())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-211ee94cf743> in <module>()
#       5 soup = BeautifulSoup(request,"html.parser")
#       6 table = soup.find_all("table", {"class": "dataTable profTable2"})
# ----> 7 trs = table.find_all("tr")
#       8 for tr in trs:
#       9     print("タイトル:", tr.find_all("p", {"class":"rightTxt"}).get_text())
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?
